# %%
import single_neuron_scratch_functions as h
import numpy as np

# %%
X, Y = h.load_flower_dataset(num_samples=500, petals=2, angle=30)
h.plot_scatter(X, Y)

# %%
## initialize parameters with zeros
w = np.zeros((X.shape[0],1))
b = 0.0

## epochs loop
num_epochs = 100
costs = []
for i in range(num_epochs):
    # Cost and gradient calculation 
    w, b, dw, db, cost = h.epoch(X, Y, w, b, learning_rate=0.05)   
    
    # Record the costs for every 10 epochs
    if i % 10 == 0 or i == num_epochs-1:
        costs.append(cost)
        print(f"Cost after epochs {i+1}, {cost}")

## Predict train set examples
Y_prediction_train = h.predict(w,b,X)

# Print train/test Errors
print("train accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - Y)) * 100))
# Out:
# Cost after epochs 1, 0.6931471805599468
# Cost after epochs 11, 0.48559532238317793
# Cost after epochs 21, 0.39789110997329163
# Cost after epochs 31, 0.3526660934247737
# Cost after epochs 41, 0.32569299308689376
# Cost after epochs 51, 0.3079583970054957
# Cost after epochs 61, 0.2954847157450173
# Cost after epochs 71, 0.2862734318537357
# Cost after epochs 81, 0.2792179964091222
# Cost after epochs 91, 0.27365854094808534
# Cost after epochs 100, 0.2695861941025166
# train accuracy: 94.6 %

# %%
h.plot_decision_boundary(w, b, X, Y)
