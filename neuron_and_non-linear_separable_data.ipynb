# %%
import single_neuron_scratch_functions as h
import numpy as np
import matplotlib.pyplot as plt

# %%
X, Y = h.load_flower_dataset(num_samples=500, petals=4)
h.plot_scatter(X, Y)

# %%
## initialize parameters with zeros
w = np.zeros((X.shape[0],1))
b = 0.0

## epochs loop
num_epochs = 100
costs = []
for i in range(num_epochs):
    # Cost and gradient calculation 
    w, b, dw, db, cost = h.epoch(X, Y, w, b, learning_rate=0.005)   
    
    # Record the costs for every 10 epochs
    if i % 10 == 0 or i == num_epochs-1:
        costs.append(cost)
        print(f"Cost after epochs {i+1}, {cost}")

## Predict train set examples
Y_prediction_train = h.predict(w,b,X)

# Print train/test Errors
print("train accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - Y)) * 100))
# Out:
# Cost after epochs 1, 0.6931471805599468
# Cost after epochs 11, 0.6901395201780097
# Cost after epochs 21, 0.6874312994260536
# Cost after epochs 31, 0.6849924431893593
# Cost after epochs 41, 0.6827957981256302
# Cost after epochs 51, 0.6808168897333793
# Cost after epochs 61, 0.6790336877859795
# Cost after epochs 71, 0.6774263833961537
# Cost after epochs 81, 0.6759771797488839
# Cost after epochs 91, 0.674670097599716
# Cost after epochs 100, 0.6736033535383487
# train accuracy: 47.4 %

# %%
h.plot_decision_boundary(w, b, X, Y)
